# %% [markdown]
#  # Visual Analysis of the Dots Dataset

# %% [markdown]
# ## import  libarires

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# ###  load dataset

# %%
# Step 1: Load the dataset
dots = sns.load_dataset("dots")
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %% [markdown]
# #### Overview of the dataset

# %%
print("Dataset Overview:")
print(dots.head())
# Out:
# Dataset Overview:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
# Explore dataset information
print("\nDataset Info:")
print(dots.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 848 entries, 0 to 847
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   align        848 non-null    object
#  1   choice       848 non-null    object
#  2   time         848 non-null    int64
#  3   coherence    848 non-null    float64
#  4   firing_rate  848 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 33.2+ KB
# None

# %%
# Describe numerical features
print("\nDataset Description:")
print(dots.describe())
# Out:
# Dataset Description:
#              time   coherence  firing_rate
# count  848.000000  848.000000   848.000000
# mean    74.150943   12.898113    39.616662
# std    284.596669   15.453506    12.232967
# min   -600.000000    0.000000     6.275720
# 25%   -100.000000    3.200000    32.620191
# 50%     80.000000    6.400000    38.022005
# 75%    260.000000   12.800000    47.383649
# max    720.000000   51.200000    70.048900

# %% [markdown]
# #### Data Cleaning

# %%
# Check for missing values
print("\nChecking for missing values:")
print(dots.isnull().sum())
# Out:
# Checking for missing values:
# align          0
# choice         0
# time           0
# coherence      0
# firing_rate    0
# dtype: int64

# %%
# Scatter plot to show the relationship between time and firing rate
plt.figure(figsize=(10, 6))
sns.scatterplot(data=dots, x="time", y="firing_rate", hue="coherence", style="choice")
plt.title("Firing Rate vs Time (Colored by Coherence and Styled by Choice)")
plt.xlabel("Time")
plt.ylabel("Firing Rate")
plt.legend(title="Coherence and Choice")
plt.show()

# %%
# Line plot to show trends over time
plt.figure(figsize=(10, 6))
sns.lineplot(data=dots, x="time", y="firing_rate", hue="coherence", style="choice", markers=True)
plt.title("Trends in Firing Rate vs Time by Coherence and Choice")
plt.xlabel("Time")
plt.ylabel("Firing Rate")
plt.legend(title="Coherence and Choice")
plt.show()

# %%
# Visualize firing rate distribution
plt.figure(figsize=(10, 6))
sns.histplot(data=dots, x="firing_rate", hue="coherence", kde=True)
plt.title("Distribution of Firing Rate by Coherence")
plt.xlabel("Firing Rate")
plt.ylabel("Frequency")
plt.show()

# %%
# Pairplot to explore multiple relationships
sns.pairplot(data=dots, hue="coherence", markers=["o", "s", "D"])
plt.suptitle("Pairplot of the Dots Dataset", y=1.02)
plt.show()
# Out:
# c:\Users\MG C\Documents\.venv\lib\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (3) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# c:\Users\MG C\Documents\.venv\lib\site-packages\seaborn\axisgrid.py:1615: UserWarning:
# The markers list has fewer values (3) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)

# %% [markdown]
# ## Conclusions

# %%
print("\nConclusions:")
print("- The dataset provides insights into how firing rates vary over time depending on coherence and choice.")
print("- The scatter and line plots reveal clear trends, with higher coherence generally leading to higher firing rates.")
print("- The distribution plot shows that the firing rate is concentrated around certain values for different levels of coherence.")
# Out:
# Conclusions:
# - The dataset provides insights into how firing rates vary over time depending on coherence and choice.
# - The scatter and line plots reveal clear trends, with higher coherence generally leading to higher firing rates.
# - The distribution plot shows that the firing rate is concentrated around certain values for different levels of coherence.
